# %%
# Visualize the cost function
# To visualize the cost function, we'll create a grid of 'm' and 'b' values and compute the cost for each combination.
m_values = np.linspace(-10, 10, 100)
b_values = np.linspace(-10, 10, 100)
cost_values = np.zeros((len(m_values), len(b_values)))

for i in range(len(m_values)):
    for j in range(len(b_values)):
        cost_values[i, j] = cost_function(X, y, m_values[i], b_values[j])

# Create a contour plot
plt.figure()
plt.contour(m_values, b_values, cost_values, levels=np.logspace(-2, 3, 20))
plt.xlabel("Slope (m)")
plt.ylabel("Intercept (b)")
plt.title("Cost Function Contour Plot")
plt.show()
